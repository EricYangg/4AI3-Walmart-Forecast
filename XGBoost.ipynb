# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
from sklearn import linear_model

from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV

# %%
url = 'https://media.githubusercontent.com/media/EricYangg/4AI3-Walmart-Forecast/main/Processed%20Dataset/x_train.csv'
x_train = pd.read_csv(url)

url = 'https://media.githubusercontent.com/media/EricYangg/4AI3-Walmart-Forecast/main/Processed%20Dataset/x_test.csv'
x_test = pd.read_csv(url)

url = 'https://media.githubusercontent.com/media/EricYangg/4AI3-Walmart-Forecast/main/Processed%20Dataset/y_train.csv'
y_train = pd.read_csv(url)

url = 'https://media.githubusercontent.com/media/EricYangg/4AI3-Walmart-Forecast/main/Processed%20Dataset/y_test.csv'
y_test = pd.read_csv(url)

# %%
x_train
# Out:
#            Store      Dept      Date  IsHoliday  Temperature  Fuel_Price  \
# 0       1.392183  1.270486 -1.288570  -0.275106    -0.036322   -1.158147
# 1      -1.188910 -0.926810 -1.361242  -0.275106    -0.731251   -1.275919
# 2      -1.188910  0.352213  1.400316  -0.275106     0.244469    0.455762
# 3       0.140744 -1.221970 -0.125808  -0.275106    -0.086734    1.853757
# 4       0.062529 -1.156379 -1.724605  -0.275106    -2.430631   -1.249747
# ...          ...       ...       ...        ...          ...         ...
# 330172  0.375389 -0.369287  1.424540  -0.275106     0.820144    0.998821
# 330173  1.392183 -0.598856 -0.610292  -0.275106    -1.946565   -0.460240
# 330174 -0.641405  0.516190  1.109625  -0.275106    -0.264532    1.286708
# 330175 -0.484975 -1.123583 -0.464947  -0.275106    -2.517904   -0.763393
# 330176 -0.719620 -0.106924  0.867383  -0.275106    -1.339450   -0.471145
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5       CPI  \
# 0       -0.427943  -0.173069  -0.084662  -0.278117  -0.395181 -0.989963
# 1       -0.427943  -0.173069  -0.084662  -0.278117  -0.395181  0.466451
# 2       -0.252011  -0.037627  -0.084038   0.046557   0.081929  0.683805
# 3       -0.427943  -0.173069  -0.084662  -0.278117  -0.395181 -0.934874
# 4       -0.427943  -0.173069  -0.084662  -0.278117  -0.395181 -1.013147
# ...           ...        ...        ...        ...        ...       ...
# 330172   6.068185  -0.134782  -0.073029   6.259835   0.356177 -0.740830
# 330173  -0.427943  -0.173069  -0.084662  -0.278117  -0.395181 -0.981996
# 330174   3.053010  -0.173069  -0.061488   1.131793   0.261853  0.503592
# 330175  -0.427943  -0.173069  -0.084662  -0.278117  -0.395181  0.525052
# 330176   2.282485   2.189758  -0.084048   0.385410   0.823210 -1.038114
#
#         Unemployment  MDAverage      MDSum     MDMin     MDMax
# 0          -1.355282  -0.271794  -1.358972 -0.427943 -0.084662
# 1           0.538139  -0.271794  -1.358972 -0.427943 -0.084662
# 2          -0.047383  -0.049038  -0.245190 -0.252011  0.081929
# 3           0.135089  -0.271794  -1.358972 -0.427943 -0.084662
# 4          -1.110017  -0.271794  -1.358972 -0.427943 -0.084662
# ...              ...        ...        ...       ...       ...
# 330172      0.149580   2.495277  12.476386 -0.134782  6.259835
# 330173     -1.434711  -0.271794  -1.358972 -0.427943 -0.084662
# 330174      0.325612   0.842420   4.212100 -0.173069  3.053010
# 330175     -0.722532  -0.271794  -1.358972 -0.427943 -0.084662
# 330176     -0.996240   1.119363   5.596815 -0.084048  2.282485
#
# [330177 rows x 17 columns]

# %%
reg = XGBRegressor(max_depth = 5, n_estimators = 150).fit(x_train,y_train)

# %%
reg.score(x_train, y_train)
# Out:
# 0.9202453633765982

# %%
reg.score(x_test, y_test)
# Out:
# 0.917340761802

# %%
y_pred = reg.predict(x_test)

# %%
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 8.16
# Coefficient of determination: 0.92

# %%
params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000],
           'colsample_bytree': [0.3, 0.7]}

# %%
xgbr = XGBRegressor(seed = 20)

# %%
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   verbose=2,
                   cv=3,
                   n_jobs=3
                   )

# %%
clf.fit(x_train, y_train)
print("Best parameters:", clf.best_params_)
print("Lowest RMSE: ", (-clf.best_score_)**(1/2.0))
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   4.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   4.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   4.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500; total time=  23.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500; total time=  23.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=500; total time=  23.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=  57.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=  58.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=  58.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   9.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   9.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   9.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500; total time=  45.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500; total time=  45.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=500; total time=  45.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000; total time= 1.5min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000; total time= 1.5min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=6, n_estimators=1000; total time= 1.5min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100; total time=  16.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100; total time=  16.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=100; total time=  16.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500; total time= 1.4min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500; total time= 1.4min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=500; total time= 1.4min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000; total time= 2.7min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000; total time= 2.7min
# [CV] END colsample_bytree=0.3, learning_rate=0.01, max_depth=10, n_estimators=1000; total time= 2.7min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   4.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   4.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   4.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500; total time=  22.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500; total time=  22.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=500; total time=  22.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=  45.0s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=  44.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=3, n_estimators=1000; total time=  45.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100; total time=   9.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100; total time=   9.4s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=100; total time=   9.5s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500; total time=  44.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500; total time=  45.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=500; total time=  45.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000; total time= 1.5min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000; total time= 1.5min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=6, n_estimators=1000; total time= 1.5min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100; total time=  16.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100; total time=  16.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=100; total time=  16.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500; total time= 1.3min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500; total time= 1.3min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=500; total time= 1.4min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000; total time= 2.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000; total time= 2.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.05, max_depth=10, n_estimators=1000; total time= 2.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   4.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   4.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   4.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500; total time=  22.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500; total time=  22.8s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=500; total time=  22.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=  45.1s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=  45.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=  45.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   9.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   9.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   9.9s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500; total time=  45.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500; total time=  45.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=500; total time=  45.3s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000; total time= 1.5min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000; total time= 1.5min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=6, n_estimators=1000; total time= 1.5min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100; total time=  18.2s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100; total time=  17.7s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=100; total time=  17.6s
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500; total time= 1.3min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500; total time= 1.3min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=500; total time= 1.3min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000; total time= 2.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000; total time= 2.6min
# [CV] END colsample_bytree=0.3, learning_rate=0.1, max_depth=10, n_estimators=1000; total time= 2.6min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   7.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   7.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   7.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500; total time=  33.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500; total time=  34.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=500; total time=  34.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000; total time= 1.1min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000; total time= 1.1min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=3, n_estimators=1000; total time= 1.1min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100; total time=  15.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100; total time=  15.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=100; total time=  15.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500; total time= 1.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500; total time= 1.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=500; total time= 1.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000; total time= 2.4min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000; total time= 2.4min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=6, n_estimators=1000; total time= 2.4min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100; total time=  27.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100; total time=  27.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=100; total time=  27.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500; total time= 2.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500; total time= 2.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=500; total time= 2.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000; total time= 4.6min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000; total time= 4.6min
# [CV] END colsample_bytree=0.7, learning_rate=0.01, max_depth=10, n_estimators=1000; total time= 4.6min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   7.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   7.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=100; total time=   7.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500; total time=  33.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500; total time=  33.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=500; total time=  33.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000; total time= 1.1min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000; total time= 1.1min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=3, n_estimators=1000; total time= 1.1min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100; total time=  14.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100; total time=  14.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=100; total time=  14.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500; total time= 1.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500; total time= 1.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=500; total time= 1.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000; total time= 2.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000; total time= 2.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=6, n_estimators=1000; total time= 2.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100; total time=  27.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100; total time=  27.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=100; total time=  27.7s
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500; total time= 2.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500; total time= 2.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=500; total time= 2.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000; total time= 4.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000; total time= 4.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.05, max_depth=10, n_estimators=1000; total time= 4.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   7.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   7.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   7.0s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500; total time=  33.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500; total time=  33.8s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=500; total time=  33.9s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000; total time= 1.1min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000; total time= 1.1min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=3, n_estimators=1000; total time= 1.1min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100; total time=  14.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100; total time=  14.5s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=100; total time=  14.6s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500; total time= 1.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500; total time= 1.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=500; total time= 1.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000; total time= 2.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000; total time= 2.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=6, n_estimators=1000; total time= 2.3min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100; total time=  27.3s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100; total time=  27.4s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=100; total time=  27.1s
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500; total time= 2.1min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500; total time= 2.1min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=500; total time= 2.1min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000; total time= 4.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000; total time= 4.2min
# [CV] END colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000; total time= 4.2min
# Best parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# Lowest RMSE:  1.3512859443634802

# %%
best_xgb = XGBRegressor(colsample_bytree=0.7, learning_rate=0.1, max_depth=10, n_estimators=1000).fit(x_train,y_train)

# %%
best_xgb.score(x_train, y_train)
# Out:
# 0.9928892898346682

# %%
best_xgb.score(x_test, y_test)
# Out:
# 0.9839574800631623

# %%
y_pred = best_xgb.predict(x_test)

# %%
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print("Coefficient of determination: %.2f" % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 1.58
# Coefficient of determination: 0.98

# %% [markdown]
# Prediction

# %%
#provided submission test dataset
url = 'https://media.githubusercontent.com/media/EricYangg/4AI3-Walmart-Forecast/main/Datasets/test.csv'
test = pd.read_csv(url)

#test dataset after preprocessing
url = 'https://media.githubusercontent.com/media/EricYangg/4AI3-Walmart-Forecast/main/Processed%20Dataset/Submission%20Test.csv'
submission_test = pd.read_csv(url)

# %% [markdown]
# Final Submission Format:
#
# Id,Weekly_Sales
#
# 1_1_2012-11-02,0
#
# 1_1_2012-11-09,0
#
# 1_1_2012-11-16,0

# %%
Id = test['Store'].astype('string') + '_' + test['Dept'].astype('string') + '_' + test['Date'].astype('string')
Id
# Out:
# 0           1_1_2012-11-02
# 1           1_1_2012-11-09
# 2           1_1_2012-11-16
# 3           1_1_2012-11-23
# 4           1_1_2012-11-30
#                 ...
# 115059    45_98_2013-06-28
# 115060    45_98_2013-07-05
# 115061    45_98_2013-07-12
# 115062    45_98_2013-07-19
# 115063    45_98_2013-07-26
# Length: 115064, dtype: string

# %%
submission_test
# Out:
#         Store  Dept  Date  IsHoliday  Temperature  Fuel_Price  MarkDown1  \
# 0       -1.66 -1.41 -1.68      -0.29         0.07       -0.82      -0.09
# 1       -1.66 -1.38 -1.68      -0.29         0.07       -0.82      -0.09
# 2       -1.66 -1.35 -1.68      -0.29         0.07       -0.82      -0.09
# 3       -1.66 -1.32 -1.68      -0.29         0.07       -0.82      -0.09
# 4       -1.66 -1.28 -1.68      -0.29         0.07       -0.82      -0.09
# ...       ...   ...   ...        ...          ...         ...        ...
# 115059   1.78  1.59  1.69      -0.29         1.18        0.93      -0.70
# 115060   1.78  1.62  1.69      -0.29         1.18        0.93      -0.70
# 115061   1.78  1.65  1.69      -0.29         1.18        0.93      -0.70
# 115062   1.78  1.72  1.69      -0.29         1.18        0.93      -0.70
# 115063   1.78  1.75  1.69      -0.29         1.18        0.93      -0.70
#
#         MarkDown2  MarkDown3  MarkDown4  MarkDown5   CPI  Unemployment  \
# 0            0.32      -0.16       0.09      -0.06  1.17          0.57
# 1            0.32      -0.16       0.09      -0.06  1.17          0.57
# 2            0.32      -0.16       0.09      -0.06  1.17          0.57
# 3            0.32      -0.16       0.09      -0.06  1.17          0.57
# 4            0.32      -0.16       0.09      -0.06  1.17          0.57
# ...           ...        ...        ...        ...   ...           ...
# 115059      -0.26      -0.17      -0.41      -0.11 -1.32         -1.32
# 115060      -0.26      -0.17      -0.41      -0.11 -1.32         -1.32
# 115061      -0.26      -0.17      -0.41      -0.11 -1.32         -1.32
# 115062      -0.26      -0.17      -0.41      -0.11 -1.32         -1.32
# 115063      -0.26      -0.17      -0.41      -0.11 -1.32         -1.32
#
#         MDAverage  MDSum  MDMin  MDMax
# 0            0.02   0.10  -0.16   0.32
# 1            0.02   0.10  -0.16   0.32
# 2            0.02   0.10  -0.16   0.32
# 3            0.02   0.10  -0.16   0.32
# 4            0.02   0.10  -0.16   0.32
# ...           ...    ...    ...    ...
# 115059      -0.33  -1.65  -0.70  -0.11
# 115060      -0.33  -1.65  -0.70  -0.11
# 115061      -0.33  -1.65  -0.70  -0.11
# 115062      -0.33  -1.65  -0.70  -0.11
# 115063      -0.33  -1.65  -0.70  -0.11
#
# [115064 rows x 17 columns]

# %%
y_pred = best_xgb.predict(submission_test)
y_pred
# Out:
# array([27.455963 , 33.92854  , 20.87351  , ..., 32.761765 , 18.676714 ,
#         7.9342856], dtype=float32)

# %%
weekly_sales = y_pred**3
weekly_sales
# Out:
# array([20697.127 , 39056.695 ,  9094.66  , ..., 35164.29  ,  6514.8047,
#          499.4862], dtype=float32)

# %%
weekly_sales[0]
# Out:
# 20697.127

# %%
sub = {'Id':Id, 'Weekly_Sales':weekly_sales}
xgb_submission = pd.DataFrame(data=sub)

xgb_submission['Weekly_Sales'] = round(xgb_submission['Weekly_Sales'], 2)

xgb_submission
# Out:
#                       Id  Weekly_Sales
# 0         1_1_2012-11-02      20697.13
# 1         1_1_2012-11-09      39056.70
# 2         1_1_2012-11-16       9094.66
# 3         1_1_2012-11-23      29936.73
# 4         1_1_2012-11-30      29278.66
# ...                  ...           ...
# 115059  45_98_2013-06-28       4478.15
# 115060  45_98_2013-07-05      12207.09
# 115061  45_98_2013-07-12      35164.29
# 115062  45_98_2013-07-19       6514.80
# 115063  45_98_2013-07-26        499.49
#
# [115064 rows x 2 columns]

# %%
xgb_submission.to_csv('Submission Files/XGBoost Best.csv', float_format='%.2f',index=False)
