# %% [markdown]
# #Initialize Data

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
url = 'https://media.githubusercontent.com/media/EricYangg/4AI3-Walmart-Forecast/main/Datasets/features.csv'
features = pd.read_csv(url)

url = 'https://media.githubusercontent.com/media/EricYangg/4AI3-Walmart-Forecast/main/Datasets/stores.csv'
stores = pd.read_csv(url)

url = 'https://media.githubusercontent.com/media/EricYangg/4AI3-Walmart-Forecast/main/Datasets/test.csv'
test = pd.read_csv(url)

url = 'https://media.githubusercontent.com/media/EricYangg/4AI3-Walmart-Forecast/main/Datasets/train.csv'
train = pd.read_csv(url)

url = 'https://media.githubusercontent.com/media/EricYangg/4AI3-Walmart-Forecast/main/Datasets/sampleSubmission.csv'
sample = pd.read_csv(url)

# %% [markdown]
# For each row in the test set (store + department + date triplet), you should predict the weekly sales of that department. The Id column is formed by concatenating the Store, Dept, and Date with underscores (e.g. Store_Dept_2012-11-02).  The file should have a header and looks like the following:

# %% [markdown]
# #Data Pre-processing:
# * Normalize the data,
# * Handle missing values,
# * Check for outliers,
# * Balance vs. imbalanced dataset,
# * Features selection

# %%
features
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  2010-02-05        42.31       2.572        NaN        NaN
# 1         1  2010-02-12        38.51       2.548        NaN        NaN
# 2         1  2010-02-19        39.93       2.514        NaN        NaN
# 3         1  2010-02-26        46.63       2.561        NaN        NaN
# 4         1  2010-03-05        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  2013-06-28        76.05       3.639    4842.29     975.03
# 8186     45  2013-07-05        77.50       3.614    9090.48    2268.58
# 8187     45  2013-07-12        79.37       3.614    3789.94    1827.31
# 8188     45  2013-07-19        82.84       3.737    2961.49    1047.07
# 8189     45  2013-07-26        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# 0           NaN        NaN        NaN  211.096358         8.106      False
# 1           NaN        NaN        NaN  211.242170         8.106       True
# 2           NaN        NaN        NaN  211.289143         8.106      False
# 3           NaN        NaN        NaN  211.319643         8.106      False
# 4           NaN        NaN        NaN  211.350143         8.106      False
# ...         ...        ...        ...         ...           ...        ...
# 8185       3.00    2449.97    3169.69         NaN           NaN      False
# 8186     582.74    5797.47    1514.93         NaN           NaN      False
# 8187      85.72     744.84    2150.36         NaN           NaN      False
# 8188     204.19     363.00    1059.46         NaN           NaN      False
# 8189       2.06      10.88    1864.57         NaN           NaN      False
#
# [8190 rows x 12 columns]

# %%
stores
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# 39     40    A  155083
# 40     41    A  196321
# 41     42    C   39690
# 42     43    C   41062
# 43     44    C   39910
# 44     45    B  118221

# %%
test
# Out:
#         Store  Dept        Date  IsHoliday
# 0           1     1  2012-11-02      False
# 1           1     1  2012-11-09      False
# 2           1     1  2012-11-16      False
# 3           1     1  2012-11-23       True
# 4           1     1  2012-11-30      False
# ...       ...   ...         ...        ...
# 115059     45    98  2013-06-28      False
# 115060     45    98  2013-07-05      False
# 115061     45    98  2013-07-12      False
# 115062     45    98  2013-07-19      False
# 115063     45    98  2013-07-26      False
#
# [115064 rows x 4 columns]

# %%
sample
# Out:
#                       Id  Weekly_Sales
# 0         1_1_2012-11-02             0
# 1         1_1_2012-11-09             0
# 2         1_1_2012-11-16             0
# 3         1_1_2012-11-23             0
# 4         1_1_2012-11-30             0
# ...                  ...           ...
# 115059  45_98_2013-06-28             0
# 115060  45_98_2013-07-05             0
# 115061  45_98_2013-07-12             0
# 115062  45_98_2013-07-19             0
# 115063  45_98_2013-07-26             0
#
# [115064 rows x 2 columns]

# %%
train
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  2010-02-05      24924.50      False
# 1           1     1  2010-02-12      46039.49       True
# 2           1     1  2010-02-19      41595.55      False
# 3           1     1  2010-02-26      19403.54      False
# 4           1     1  2010-03-05      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  2012-09-28        508.37      False
# 421566     45    98  2012-10-05        628.10      False
# 421567     45    98  2012-10-12       1061.02      False
# 421568     45    98  2012-10-19        760.01      False
# 421569     45    98  2012-10-26       1076.80      False
#
# [421570 rows x 5 columns]

# %%
feature_train = pd.merge(train,features, on=['Store','Date','IsHoliday'])
feature_train
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  2010-02-05      24924.50      False        42.31
# 1           1     2  2010-02-05      50605.27      False        42.31
# 2           1     3  2010-02-05      13740.12      False        42.31
# 3           1     4  2010-02-05      39954.04      False        42.31
# 4           1     5  2010-02-05      32229.38      False        42.31
# ...       ...   ...         ...           ...        ...          ...
# 421565     45    93  2012-10-26       2487.80      False        58.85
# 421566     45    94  2012-10-26       5203.31      False        58.85
# 421567     45    95  2012-10-26      56017.47      False        58.85
# 421568     45    97  2012-10-26       6817.48      False        58.85
# 421569     45    98  2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# 0            2.572        NaN        NaN        NaN        NaN        NaN
# 1            2.572        NaN        NaN        NaN        NaN        NaN
# 2            2.572        NaN        NaN        NaN        NaN        NaN
# 3            2.572        NaN        NaN        NaN        NaN        NaN
# 4            2.572        NaN        NaN        NaN        NaN        NaN
# ...            ...        ...        ...        ...        ...        ...
# 421565       3.882    4018.91      58.08      100.0     211.94     858.33
# 421566       3.882    4018.91      58.08      100.0     211.94     858.33
# 421567       3.882    4018.91      58.08      100.0     211.94     858.33
# 421568       3.882    4018.91      58.08      100.0     211.94     858.33
# 421569       3.882    4018.91      58.08      100.0     211.94     858.33
#
#                CPI  Unemployment
# 0       211.096358         8.106
# 1       211.096358         8.106
# 2       211.096358         8.106
# 3       211.096358         8.106
# 4       211.096358         8.106
# ...            ...           ...
# 421565  192.308899         8.667
# 421566  192.308899         8.667
# 421567  192.308899         8.667
# 421568  192.308899         8.667
# 421569  192.308899         8.667
#
# [421570 rows x 14 columns]

# %%
train_labels = feature_train['Weekly_Sales']
train_labels
# Out:
# 0         24924.50
# 1         50605.27
# 2         13740.12
# 3         39954.04
# 4         32229.38
#             ...
# 421565     2487.80
# 421566     5203.31
# 421567    56017.47
# 421568     6817.48
# 421569     1076.80
# Name: Weekly_Sales, Length: 421570, dtype: float64

# %%
feature_train = feature_train.drop(columns=['Weekly_Sales'])
feature_train
# Out:
#         Store  Dept        Date  IsHoliday  Temperature  Fuel_Price  \
# 0           1     1  2010-02-05      False        42.31       2.572
# 1           1     2  2010-02-05      False        42.31       2.572
# 2           1     3  2010-02-05      False        42.31       2.572
# 3           1     4  2010-02-05      False        42.31       2.572
# 4           1     5  2010-02-05      False        42.31       2.572
# ...       ...   ...         ...        ...          ...         ...
# 421565     45    93  2012-10-26      False        58.85       3.882
# 421566     45    94  2012-10-26      False        58.85       3.882
# 421567     45    95  2012-10-26      False        58.85       3.882
# 421568     45    97  2012-10-26      False        58.85       3.882
# 421569     45    98  2012-10-26      False        58.85       3.882
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0             NaN        NaN        NaN        NaN        NaN  211.096358
# 1             NaN        NaN        NaN        NaN        NaN  211.096358
# 2             NaN        NaN        NaN        NaN        NaN  211.096358
# 3             NaN        NaN        NaN        NaN        NaN  211.096358
# 4             NaN        NaN        NaN        NaN        NaN  211.096358
# ...           ...        ...        ...        ...        ...         ...
# 421565    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421566    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421567    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421568    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421569    4018.91      58.08      100.0     211.94     858.33  192.308899
#
#         Unemployment
# 0              8.106
# 1              8.106
# 2              8.106
# 3              8.106
# 4              8.106
# ...              ...
# 421565         8.667
# 421566         8.667
# 421567         8.667
# 421568         8.667
# 421569         8.667
#
# [421570 rows x 13 columns]

# %%
feature_test = pd.merge(test,features, on=['Store','Date','IsHoliday'])
feature_test
# Out:
#         Store  Dept        Date  IsHoliday  Temperature  Fuel_Price  \
# 0           1     1  2012-11-02      False        55.32       3.386
# 1           1     2  2012-11-02      False        55.32       3.386
# 2           1     3  2012-11-02      False        55.32       3.386
# 3           1     4  2012-11-02      False        55.32       3.386
# 4           1     5  2012-11-02      False        55.32       3.386
# ...       ...   ...         ...        ...          ...         ...
# 115059     45    93  2013-07-26      False        76.06       3.804
# 115060     45    94  2013-07-26      False        76.06       3.804
# 115061     45    95  2013-07-26      False        76.06       3.804
# 115062     45    97  2013-07-26      False        76.06       3.804
# 115063     45    98  2013-07-26      False        76.06       3.804
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# 1         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# 2         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# 3         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# 4         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# ...           ...        ...        ...        ...        ...         ...
# 115059     212.02     851.73       2.06      10.88    1864.57         NaN
# 115060     212.02     851.73       2.06      10.88    1864.57         NaN
# 115061     212.02     851.73       2.06      10.88    1864.57         NaN
# 115062     212.02     851.73       2.06      10.88    1864.57         NaN
# 115063     212.02     851.73       2.06      10.88    1864.57         NaN
#
#         Unemployment
# 0              6.573
# 1              6.573
# 2              6.573
# 3              6.573
# 4              6.573
# ...              ...
# 115059           NaN
# 115060           NaN
# 115061           NaN
# 115062           NaN
# 115063           NaN
#
# [115064 rows x 13 columns]

# %% [markdown]
# #Handle Missing Values

# %%
feature_train.isnull().sum()
# Out:
# Store                0
# Dept                 0
# Date                 0
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# MarkDown1       270889
# MarkDown2       310322
# MarkDown3       284479
# MarkDown4       286603
# MarkDown5       270138
# CPI                  0
# Unemployment         0
# dtype: int64

# %%
feature_train['MarkDown1'].value_counts()
# Out:
# 1.50       102
# 460.73     102
# 175.64      93
# 9264.48     75
# 1483.17     75
#           ...
# 196.40      42
# 243.47      42
# 512.15      42
# 318.51      42
# 945.96      42
# Name: MarkDown1, Length: 2277, dtype: int64

# %%
feature_train.shape
# Out:
# (421570, 13)

# %% [markdown]
# The markdowns are the only features with the training set that have missing values and we will be replacing them with 0 rather than dropping them due to the fact that it would drop about 3/4th of the rows and if we use these features with our testing set, we won't be able to drop them and will need a placeholder value instead. What that value is whether it be 0 or an average will be determined later

# %%
feature_train = feature_train.fillna(0)
feature_train
# Out:
#         Store  Dept        Date  IsHoliday  Temperature  Fuel_Price  \
# 0           1     1  2010-02-05      False        42.31       2.572
# 1           1     2  2010-02-05      False        42.31       2.572
# 2           1     3  2010-02-05      False        42.31       2.572
# 3           1     4  2010-02-05      False        42.31       2.572
# 4           1     5  2010-02-05      False        42.31       2.572
# ...       ...   ...         ...        ...          ...         ...
# 421565     45    93  2012-10-26      False        58.85       3.882
# 421566     45    94  2012-10-26      False        58.85       3.882
# 421567     45    95  2012-10-26      False        58.85       3.882
# 421568     45    97  2012-10-26      False        58.85       3.882
# 421569     45    98  2012-10-26      False        58.85       3.882
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0            0.00       0.00        0.0       0.00       0.00  211.096358
# 1            0.00       0.00        0.0       0.00       0.00  211.096358
# 2            0.00       0.00        0.0       0.00       0.00  211.096358
# 3            0.00       0.00        0.0       0.00       0.00  211.096358
# 4            0.00       0.00        0.0       0.00       0.00  211.096358
# ...           ...        ...        ...        ...        ...         ...
# 421565    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421566    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421567    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421568    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421569    4018.91      58.08      100.0     211.94     858.33  192.308899
#
#         Unemployment
# 0              8.106
# 1              8.106
# 2              8.106
# 3              8.106
# 4              8.106
# ...              ...
# 421565         8.667
# 421566         8.667
# 421567         8.667
# 421568         8.667
# 421569         8.667
#
# [421570 rows x 13 columns]

# %%
feature_train.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# IsHoliday       0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# dtype: int64

# %% [markdown]
# As for the missing value handling for the testing set, we will make changes on these missing values based on our feature selection, as if we find some to be not useful, we will drop them

# %%
feature_test.isnull().sum()
# Out:
# Store               0
# Dept                0
# Date                0
# IsHoliday           0
# Temperature         0
# Fuel_Price          0
# MarkDown1         149
# MarkDown2       28627
# MarkDown3        9829
# MarkDown4       12888
# MarkDown5           0
# CPI             38162
# Unemployment    38162
# dtype: int64

# %%
feature_test = feature_test.fillna(0)
feature_test
# Out:
#         Store  Dept                 Date  IsHoliday  Temperature  Fuel_Price  \
# 0           1     1  1351814400000000000          0        55.32       3.386
# 1           1     2  1351814400000000000          0        55.32       3.386
# 2           1     3  1351814400000000000          0        55.32       3.386
# 3           1     4  1351814400000000000          0        55.32       3.386
# 4           1     5  1351814400000000000          0        55.32       3.386
# ...       ...   ...                  ...        ...          ...         ...
# 115059     45    93  1374796800000000000          0        76.06       3.804
# 115060     45    94  1374796800000000000          0        76.06       3.804
# 115061     45    95  1374796800000000000          0        76.06       3.804
# 115062     45    97  1374796800000000000          0        76.06       3.804
# 115063     45    98  1374796800000000000          0        76.06       3.804
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# 1         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# 2         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# 3         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# 4         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# ...           ...        ...        ...        ...        ...         ...
# 115059     212.02     851.73       2.06      10.88    1864.57    0.000000
# 115060     212.02     851.73       2.06      10.88    1864.57    0.000000
# 115061     212.02     851.73       2.06      10.88    1864.57    0.000000
# 115062     212.02     851.73       2.06      10.88    1864.57    0.000000
# 115063     212.02     851.73       2.06      10.88    1864.57    0.000000
#
#         Unemployment
# 0              6.573
# 1              6.573
# 2              6.573
# 3              6.573
# 4              6.573
# ...              ...
# 115059         0.000
# 115060         0.000
# 115061         0.000
# 115062         0.000
# 115063         0.000
#
# [115064 rows x 13 columns]

# %%
feature_test.isnull().sum()
# Out:
# Store           0
# Dept            0
# Date            0
# IsHoliday       0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# dtype: int64

# %% [markdown]
# #Normalize Data

# %%
feature_train
# Out:
#         Store  Dept        Date  IsHoliday  Temperature  Fuel_Price  \
# 0           1     1  2010-02-05      False        42.31       2.572
# 1           1     2  2010-02-05      False        42.31       2.572
# 2           1     3  2010-02-05      False        42.31       2.572
# 3           1     4  2010-02-05      False        42.31       2.572
# 4           1     5  2010-02-05      False        42.31       2.572
# ...       ...   ...         ...        ...          ...         ...
# 421565     45    93  2012-10-26      False        58.85       3.882
# 421566     45    94  2012-10-26      False        58.85       3.882
# 421567     45    95  2012-10-26      False        58.85       3.882
# 421568     45    97  2012-10-26      False        58.85       3.882
# 421569     45    98  2012-10-26      False        58.85       3.882
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0            0.00       0.00        0.0       0.00       0.00  211.096358
# 1            0.00       0.00        0.0       0.00       0.00  211.096358
# 2            0.00       0.00        0.0       0.00       0.00  211.096358
# 3            0.00       0.00        0.0       0.00       0.00  211.096358
# 4            0.00       0.00        0.0       0.00       0.00  211.096358
# ...           ...        ...        ...        ...        ...         ...
# 421565    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421566    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421567    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421568    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421569    4018.91      58.08      100.0     211.94     858.33  192.308899
#
#         Unemployment
# 0              8.106
# 1              8.106
# 2              8.106
# 3              8.106
# 4              8.106
# ...              ...
# 421565         8.667
# 421566         8.667
# 421567         8.667
# 421568         8.667
# 421569         8.667
#
# [421570 rows x 13 columns]

# %%
#change date and IsHoliday data type
feature_train['Date'] = pd.to_datetime(feature_train['Date']).astype('int64')
feature_train['IsHoliday'] = feature_train['IsHoliday']*1 
feature_train
# Out:
#         Store  Dept                 Date  IsHoliday  Temperature  Fuel_Price  \
# 0           1     1  1265328000000000000          0        42.31       2.572
# 1           1     2  1265328000000000000          0        42.31       2.572
# 2           1     3  1265328000000000000          0        42.31       2.572
# 3           1     4  1265328000000000000          0        42.31       2.572
# 4           1     5  1265328000000000000          0        42.31       2.572
# ...       ...   ...                  ...        ...          ...         ...
# 421565     45    93  1351209600000000000          0        58.85       3.882
# 421566     45    94  1351209600000000000          0        58.85       3.882
# 421567     45    95  1351209600000000000          0        58.85       3.882
# 421568     45    97  1351209600000000000          0        58.85       3.882
# 421569     45    98  1351209600000000000          0        58.85       3.882
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0            0.00       0.00        0.0       0.00       0.00  211.096358
# 1            0.00       0.00        0.0       0.00       0.00  211.096358
# 2            0.00       0.00        0.0       0.00       0.00  211.096358
# 3            0.00       0.00        0.0       0.00       0.00  211.096358
# 4            0.00       0.00        0.0       0.00       0.00  211.096358
# ...           ...        ...        ...        ...        ...         ...
# 421565    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421566    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421567    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421568    4018.91      58.08      100.0     211.94     858.33  192.308899
# 421569    4018.91      58.08      100.0     211.94     858.33  192.308899
#
#         Unemployment
# 0              8.106
# 1              8.106
# 2              8.106
# 3              8.106
# 4              8.106
# ...              ...
# 421565         8.667
# 421566         8.667
# 421567         8.667
# 421568         8.667
# 421569         8.667
#
# [421570 rows x 13 columns]

# %%
#change date and IsHoliday data type
feature_test['Date'] = pd.to_datetime(feature_test['Date']).astype('int64')
feature_test['IsHoliday'] = feature_test['IsHoliday']*1 
feature_test
# Out:
#         Store  Dept                 Date  IsHoliday  Temperature  Fuel_Price  \
# 0           1     1  1351814400000000000          0        55.32       3.386
# 1           1     2  1351814400000000000          0        55.32       3.386
# 2           1     3  1351814400000000000          0        55.32       3.386
# 3           1     4  1351814400000000000          0        55.32       3.386
# 4           1     5  1351814400000000000          0        55.32       3.386
# ...       ...   ...                  ...        ...          ...         ...
# 115059     45    93  1374796800000000000          0        76.06       3.804
# 115060     45    94  1374796800000000000          0        76.06       3.804
# 115061     45    95  1374796800000000000          0        76.06       3.804
# 115062     45    97  1374796800000000000          0        76.06       3.804
# 115063     45    98  1374796800000000000          0        76.06       3.804
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# 1         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# 2         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# 3         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# 4         6766.44    5147.70      50.82    3639.90    2737.42  223.462779
# ...           ...        ...        ...        ...        ...         ...
# 115059     212.02     851.73       2.06      10.88    1864.57         NaN
# 115060     212.02     851.73       2.06      10.88    1864.57         NaN
# 115061     212.02     851.73       2.06      10.88    1864.57         NaN
# 115062     212.02     851.73       2.06      10.88    1864.57         NaN
# 115063     212.02     851.73       2.06      10.88    1864.57         NaN
#
#         Unemployment
# 0              6.573
# 1              6.573
# 2              6.573
# 3              6.573
# 4              6.573
# ...              ...
# 115059           NaN
# 115060           NaN
# 115061           NaN
# 115062           NaN
# 115063           NaN
#
# [115064 rows x 13 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
feature_train_scaled = scaler.fit_transform(feature_train)
feature_train_scaled
# Out:
# array([[-1.65819926, -1.41874236, -1.72460527, ..., -0.39518081,
#          1.01877417,  0.07820093],
#        [-1.65819926, -1.38594689, -1.72460527, ..., -0.39518081,
#          1.01877417,  0.07820093],
#        [-1.65819926, -1.35315142, -1.72460527, ..., -0.39518081,
#          1.01877417,  0.07820093],
#        ...,
#        [ 1.78325781,  1.66403164,  1.71523026, ..., -0.19118684,
#          0.53900326,  0.37928066],
#        [ 1.78325781,  1.72962258,  1.71523026, ..., -0.19118684,
#          0.53900326,  0.37928066],
#        [ 1.78325781,  1.76241805,  1.71523026, ..., -0.19118684,
#          0.53900326,  0.37928066]])

# %%
feature_test_scaled = scaler.fit_transform(feature_test)
feature_test_scaled
# Out:
# array([[-1.65795594, -1.41372432, -1.68305502, ..., -0.06095434,
#          1.17038956,  0.56909549],
#        [-1.65795594, -1.38110457, -1.68305502, ..., -0.06095434,
#          1.17038956,  0.56909549],
#        [-1.65795594, -1.34848482, -1.68305502, ..., -0.06095434,
#          1.17038956,  0.56909549],
#        ...,
#        [ 1.77689441,  1.65253191,  1.69293182, ..., -0.10584233,
#         -1.31590133, -1.31789582],
#        [ 1.77689441,  1.71777141,  1.69293182, ..., -0.10584233,
#         -1.31590133, -1.31789582],
#        [ 1.77689441,  1.75039115,  1.69293182, ..., -0.10584233,
#         -1.31590133, -1.31789582]])

# %% [markdown]
# #Check for outliers

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(8, 11))
ax = sns.boxplot(data=train_labels)
#ax.set_xticklabels('Weekly Sale')
ax.set_title('Boxplot of Weekly Sales Dataset')
ax.set_xlabel('Weekly Sales')
plt.show()

# %% [markdown]
# Removing entries/outliers outside of of +- 3 for z score

# %%
import scipy.stats as stats

z = np.abs(stats.zscore(train_labels))

#only keep rows in dataframe with all z-scores less than absolute value of 3 
train_labels_clean = train_labels[(z<3)]

print('New shape:', train_labels_clean.shape)
print('Number of outliers removed: ', (train_labels.shape[0]-train_labels_clean.shape[0]))
# Out:
# New shape: (412722,)
# Number of outliers removed:  8848

# %%
fig, ax = plt.subplots(figsize=(8, 11))
ax = sns.boxplot(data=train_labels_clean)
ax.set_title('Boxplot of Weekly Sales Dataset')
ax.set_xlabel('Weekly Sales')
plt.show()

# %%
#filter out the outliers removed for features dataset on the labels dataset 
feature_train_scaled_clean = feature_train_scaled[train_labels_clean.index, :]
print(feature_train_scaled_clean.shape)
print(feature_train_scaled_clean)
# Out:
# (412722, 13)
# [[-1.65819926 -1.41874236 -1.72460527 ... -0.39518081  1.01877417
#    0.07820093]
#  [-1.65819926 -1.38594689 -1.72460527 ... -0.39518081  1.01877417
#    0.07820093]
#  [-1.65819926 -1.35315142 -1.72460527 ... -0.39518081  1.01877417
#    0.07820093]
#  ...
#  [ 1.78325781  1.66403164  1.71523026 ... -0.19118684  0.53900326
#    0.37928066]
#  [ 1.78325781  1.72962258  1.71523026 ... -0.19118684  0.53900326
#    0.37928066]
#  [ 1.78325781  1.76241805  1.71523026 ... -0.19118684  0.53900326
#    0.37928066]]

# %% [markdown]
# #Balance vs Imbalanced Dataset

# %%
train_labels_clean.hist(bins=250)
plt.title('Histogram of Weekly Sales')
plt.xlabel('Weekly Sales')
plt.ylabel('Count of Weekly Sales Amount')
plt.show()

# %%
np.cbrt(train_labels_clean).hist(bins=100)
plt.title('Histogram of Weekly Sales - cbrt')
plt.xlabel('Weekly Sales')
plt.ylabel('Count of Weekly Sales Amount')
plt.show()

# %%
final_labels = np.cbrt(train_labels_clean)
final_labels
# Out:
# 0         29.210713
# 1         36.988375
# 2         23.951360
# 3         34.186415
# 4         31.823698
#             ...
# 421565    13.549975
# 421566    17.328457
# 421567    38.262602
# 421568    18.961584
# 421569    10.249712
# Name: Weekly_Sales, Length: 412722, dtype: float64

# %%
df_final_features = pd.DataFrame(feature_train_scaled_clean, columns =feature_train.columns)

# %%
df_final_features.iloc[:,6:11]
# Out:
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5
# 0       -0.427943  -0.173069  -0.084662  -0.278117  -0.395181
# 1       -0.427943  -0.173069  -0.084662  -0.278117  -0.395181
# 2       -0.427943  -0.173069  -0.084662  -0.278117  -0.395181
# 3       -0.427943  -0.173069  -0.084662  -0.278117  -0.395181
# 4       -0.427943  -0.173069  -0.084662  -0.278117  -0.395181
# ...           ...        ...        ...        ...        ...
# 412717   0.236078  -0.161646  -0.066576  -0.223697  -0.191187
# 412718   0.236078  -0.161646  -0.066576  -0.223697  -0.191187
# 412719   0.236078  -0.161646  -0.066576  -0.223697  -0.191187
# 412720   0.236078  -0.161646  -0.066576  -0.223697  -0.191187
# 412721   0.236078  -0.161646  -0.066576  -0.223697  -0.191187
#
# [412722 rows x 5 columns]

# %%
df_final_features.iloc[:,6:11].mean(axis=1)
# Out:
# 0        -0.271794
# 1        -0.271794
# 2        -0.271794
# 3        -0.271794
# 4        -0.271794
#             ...
# 412717   -0.081405
# 412718   -0.081405
# 412719   -0.081405
# 412720   -0.081405
# 412721   -0.081405
# Length: 412722, dtype: float64

# %%
df_final_features['MDAverage'] = df_final_features.iloc[:,6:11].mean(axis=1)
df_final_features['MDSum'] = df_final_features.iloc[:,6:11].sum(axis=1)
df_final_features['MDMin'] = df_final_features.iloc[:,6:11].min(axis=1)
df_final_features['MDMax'] = df_final_features.iloc[:,6:11].max(axis=1)

# %%
final_features = df_final_features.to_numpy()

# %%
final_features.shape[1]
# Out:
# 17

# %%
df_final_test_features = pd.DataFrame(feature_test_scaled, columns =feature_train.columns)
df_final_test_features['MDAverage'] = df_final_test_features.iloc[:,6:11].mean(axis=1)
df_final_test_features['MDSum'] = df_final_test_features.iloc[:,6:11].sum(axis=1)
df_final_test_features['MDMin'] = df_final_test_features.iloc[:,6:11].min(axis=1)
df_final_test_features['MDMax'] = df_final_test_features.iloc[:,6:11].max(axis=1)
final_test_features = df_final_test_features.to_numpy()
df_final_test_features
# Out:
#            Store      Dept      Date  IsHoliday  Temperature  Fuel_Price  \
# 0      -1.657956 -1.413724 -1.683055  -0.290032     0.073606   -0.816679
# 1      -1.657956 -1.381105 -1.683055  -0.290032     0.073606   -0.816679
# 2      -1.657956 -1.348485 -1.683055  -0.290032     0.073606   -0.816679
# 3      -1.657956 -1.315865 -1.683055  -0.290032     0.073606   -0.816679
# 4      -1.657956 -1.283245 -1.683055  -0.290032     0.073606   -0.816679
# ...          ...       ...       ...        ...          ...         ...
# 115059  1.776894  1.587292  1.692932  -0.290032     1.181271    0.929055
# 115060  1.776894  1.619912  1.692932  -0.290032     1.181271    0.929055
# 115061  1.776894  1.652532  1.692932  -0.290032     1.181271    0.929055
# 115062  1.776894  1.717771  1.692932  -0.290032     1.181271    0.929055
# 115063  1.776894  1.750391  1.692932  -0.290032     1.181271    0.929055
#
#         MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5       CPI  \
# 0       -0.085347   0.316895  -0.162850   0.091459  -0.060954  1.170390
# 1       -0.085347   0.316895  -0.162850   0.091459  -0.060954  1.170390
# 2       -0.085347   0.316895  -0.162850   0.091459  -0.060954  1.170390
# 3       -0.085347   0.316895  -0.162850   0.091459  -0.060954  1.170390
# 4       -0.085347   0.316895  -0.162850   0.091459  -0.060954  1.170390
# ...           ...        ...        ...        ...        ...       ...
# 115059  -0.698176  -0.264229  -0.166549  -0.411733  -0.105842 -1.315901
# 115060  -0.698176  -0.264229  -0.166549  -0.411733  -0.105842 -1.315901
# 115061  -0.698176  -0.264229  -0.166549  -0.411733  -0.105842 -1.315901
# 115062  -0.698176  -0.264229  -0.166549  -0.411733  -0.105842 -1.315901
# 115063  -0.698176  -0.264229  -0.166549  -0.411733  -0.105842 -1.315901
#
#         Unemployment  MDAverage     MDSum     MDMin     MDMax
# 0           0.569095   0.019840  0.099201 -0.162850  0.316895
# 1           0.569095   0.019840  0.099201 -0.162850  0.316895
# 2           0.569095   0.019840  0.099201 -0.162850  0.316895
# 3           0.569095   0.019840  0.099201 -0.162850  0.316895
# 4           0.569095   0.019840  0.099201 -0.162850  0.316895
# ...              ...        ...       ...       ...       ...
# 115059     -1.317896  -0.329306 -1.646529 -0.698176 -0.105842
# 115060     -1.317896  -0.329306 -1.646529 -0.698176 -0.105842
# 115061     -1.317896  -0.329306 -1.646529 -0.698176 -0.105842
# 115062     -1.317896  -0.329306 -1.646529 -0.698176 -0.105842
# 115063     -1.317896  -0.329306 -1.646529 -0.698176 -0.105842
#
# [115064 rows x 17 columns]

# %% [markdown]
# #Feature selection

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()

# %%
scores = []

# %%
#testing each feature 
for i in range(final_features.shape[1]):
    temp_train = final_features[:,i].reshape(-1, 1)
    model.fit(temp_train, final_labels)
    scores.append(model.score(temp_train,final_labels))

# %%
scores
# Out:
# [0.010258467058118281,
#  0.0006161780181603849,
#  6.080727539348185e-05,
#  1.3425095803931697e-05,
#  0.00028672877159852117,
#  5.779071924338908e-07,
#  0.003222929213519854,
#  0.0006101498226765978,
#  0.000526816319086354,
#  0.0017329768879473795,
#  0.002810155996216923,
#  0.000865890901337818,
#  0.0007919920485753851,
#  0.004417807863469125,
#  0.004417807863469458,
#  0.0028138833154881526,
#  0.0034762611429434154]

# %%
len(scores)
# Out:
# 17

# %%
names=list(df_final_features) #feature names
scores=np.array(scores) 
top=scores.argsort()[-17:][::-1] #get index of top 3 scores

print('Features score ordered: ')
for i in range(len(top)):
  print(i+1,". ", names[top[i]]," with a score of ",scores[top[i]],sep="")
# Out:
# Features score ordered:
# 1. Store with a score of 0.010258467058118281
# 2. MDSum with a score of 0.004417807863469458
# 3. MDAverage with a score of 0.004417807863469125
# 4. MDMax with a score of 0.0034762611429434154
# 5. MarkDown1 with a score of 0.003222929213519854
# 6. MDMin with a score of 0.0028138833154881526
# 7. MarkDown5 with a score of 0.002810155996216923
# 8. MarkDown4 with a score of 0.0017329768879473795
# 9. CPI with a score of 0.000865890901337818
# 10. Unemployment with a score of 0.0007919920485753851
# 11. Dept with a score of 0.0006161780181603849
# 12. MarkDown2 with a score of 0.0006101498226765978
# 13. MarkDown3 with a score of 0.000526816319086354
# 14. Temperature with a score of 0.00028672877159852117
# 15. Date with a score of 6.080727539348185e-05
# 16. IsHoliday with a score of 1.3425095803931697e-05
# 17. Fuel_Price with a score of 5.779071924338908e-07

# %%
from sklearn.feature_selection import SelectKBest, mutual_info_regression

# %%
#Select top feature based on mutual info regression
selector = SelectKBest(mutual_info_regression, k =1)
selector.fit(final_features, final_labels)
df_final_features.columns[selector.get_support()]
# Out:
# Index(['Dept'], dtype='object')

# %%
#Select top 3 features based on mutual info regression
selector = SelectKBest(mutual_info_regression, k =3)
selector.fit(final_features, final_labels)
df_final_features.columns[selector.get_support()]
# Out:
# Index(['Store', 'Dept', 'Unemployment'], dtype='object')

# %%
#Select top 5 features based on mutual info regression
selector = SelectKBest(mutual_info_regression, k =5)
selector.fit(final_features, final_labels)
df_final_features.columns[selector.get_support()]
# Out:
# Index(['Store', 'Dept', 'CPI', 'Unemployment', 'MDSum'], dtype='object')

# %%
#Select top 7 features based on mutual info regression
selector = SelectKBest(mutual_info_regression, k =7)
selector.fit(final_features, final_labels)
df_final_features.columns[selector.get_support()]
# Out:
# Index(['Store', 'Dept', 'CPI', 'Unemployment', 'MDAverage', 'MDSum', 'MDMin'], dtype='object')

# %%
#Select top 10 features based on mutual info regression
selector = SelectKBest(mutual_info_regression, k =10)
selector.fit(final_features, final_labels)
df_final_features.columns[selector.get_support()]
# Out:
# Index(['Store', 'Dept', 'MarkDown1', 'MarkDown5', 'CPI', 'Unemployment',
#        'MDAverage', 'MDSum', 'MDMin', 'MDMax'],
#       dtype='object')

# %%
#Select top 13 features based on mutual info regression
selector = SelectKBest(mutual_info_regression, k =13)
selector.fit(final_features, final_labels)
top13_SelectK = df_final_features.columns[selector.get_support()]
top13_SelectK
# Out:
# Index(['Store', 'Dept', 'Temperature', 'MarkDown1', 'MarkDown3', 'MarkDown4',
#        'MarkDown5', 'CPI', 'Unemployment', 'MDAverage', 'MDSum', 'MDMin',
#        'MDMax'],
#       dtype='object')

# %% [markdown]
# Split Dataset into train and test

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(df_final_features, final_labels, test_size=0.2, random_state=42)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (330177, 17)
# (82545, 17)
# (330177,)
# (82545,)

# %%
x_train.to_csv('Processed Dataset/x_train.csv',index=False)
x_test.to_csv('Processed Dataset/x_test.csv',index=False)
y_train.to_csv('Processed Dataset/y_train.csv',index=False)
y_test.to_csv('Processed Dataset/y_test.csv',index=False)

# %%
df_final_test_features.to_csv('Processed Dataset/Submission Test.csv',index=False)

# %% [markdown]
# Split Dataset based on Feature Selection - Top 13

# %% [markdown]
# Linear Reg Feature Selection

# %%
df_final_features_LinReg = df_final_features.iloc[:,top[0:13]]
df_final_features_LinReg
# Out:
#            Store     MDSum  MDAverage     MDMax  MarkDown1     MDMin  \
# 0      -1.658199 -1.358972  -0.271794 -0.084662  -0.427943 -0.427943
# 1      -1.658199 -1.358972  -0.271794 -0.084662  -0.427943 -0.427943
# 2      -1.658199 -1.358972  -0.271794 -0.084662  -0.427943 -0.427943
# 3      -1.658199 -1.358972  -0.271794 -0.084662  -0.427943 -0.427943
# 4      -1.658199 -1.358972  -0.271794 -0.084662  -0.427943 -0.427943
# ...          ...       ...        ...       ...        ...       ...
# 412717  1.783258 -0.407027  -0.081405  0.236078   0.236078 -0.223697
# 412718  1.783258 -0.407027  -0.081405  0.236078   0.236078 -0.223697
# 412719  1.783258 -0.407027  -0.081405  0.236078   0.236078 -0.223697
# 412720  1.783258 -0.407027  -0.081405  0.236078   0.236078 -0.223697
# 412721  1.783258 -0.407027  -0.081405  0.236078   0.236078 -0.223697
#
#         MarkDown5  MarkDown4       CPI  Unemployment      Dept  MarkDown2  \
# 0       -0.395181  -0.278117  1.018774      0.078201 -1.418742  -0.173069
# 1       -0.395181  -0.278117  1.018774      0.078201 -1.385947  -0.173069
# 2       -0.395181  -0.278117  1.018774      0.078201 -1.353151  -0.173069
# 3       -0.395181  -0.278117  1.018774      0.078201 -1.320356  -0.173069
# 4       -0.395181  -0.278117  1.018774      0.078201 -1.287560  -0.173069
# ...           ...        ...       ...           ...       ...        ...
# 412717  -0.191187  -0.223697  0.539003      0.379281  1.598441  -0.161646
# 412718  -0.191187  -0.223697  0.539003      0.379281  1.631236  -0.161646
# 412719  -0.191187  -0.223697  0.539003      0.379281  1.664032  -0.161646
# 412720  -0.191187  -0.223697  0.539003      0.379281  1.729623  -0.161646
# 412721  -0.191187  -0.223697  0.539003      0.379281  1.762418  -0.161646
#
#         MarkDown3
# 0       -0.084662
# 1       -0.084662
# 2       -0.084662
# 3       -0.084662
# 4       -0.084662
# ...           ...
# 412717  -0.066576
# 412718  -0.066576
# 412719  -0.066576
# 412720  -0.066576
# 412721  -0.066576
#
# [412722 rows x 13 columns]

# %%
LinReg_x_train, LinReg_x_test, LinReg_y_train, LinReg_y_test = train_test_split(df_final_features_LinReg, final_labels, test_size=0.2, random_state=42)
print(LinReg_x_train.shape)
print(LinReg_x_test.shape)
print(LinReg_y_train.shape)
print(LinReg_y_test.shape)
# Out:
# (330177, 13)
# (82545, 13)
# (330177,)
# (82545,)

# %%
LinReg_x_train.to_csv('Processed Dataset/Lin Reg Feature Selection/x_train.csv',index=False)
LinReg_x_test.to_csv('Processed Dataset/Lin Reg Feature Selection/x_test.csv',index=False)
LinReg_y_train.to_csv('Processed Dataset/Lin Reg Feature Selection/y_train.csv',index=False)
LinReg_y_test.to_csv('Processed Dataset/Lin Reg Feature Selection/y_test.csv',index=False)

# %% [markdown]
# SelectKBest Feature Selection

# %%
df_final_features_SelectK = df_final_features[top13_SelectK]
df_final_features_SelectK
# Out:
#            Store      Dept  Temperature  MarkDown1  MarkDown3  MarkDown4  \
# 0      -1.658199 -1.418742    -0.963798  -0.427943  -0.084662  -0.278117
# 1      -1.658199 -1.385947    -0.963798  -0.427943  -0.084662  -0.278117
# 2      -1.658199 -1.353151    -0.963798  -0.427943  -0.084662  -0.278117
# 3      -1.658199 -1.320356    -0.963798  -0.427943  -0.084662  -0.278117
# 4      -1.658199 -1.287560    -0.963798  -0.427943  -0.084662  -0.278117
# ...          ...       ...          ...        ...        ...        ...
# 412717  1.783258  1.598441    -0.067219   0.236078  -0.066576  -0.223697
# 412718  1.783258  1.631236    -0.067219   0.236078  -0.066576  -0.223697
# 412719  1.783258  1.664032    -0.067219   0.236078  -0.066576  -0.223697
# 412720  1.783258  1.729623    -0.067219   0.236078  -0.066576  -0.223697
# 412721  1.783258  1.762418    -0.067219   0.236078  -0.066576  -0.223697
#
#         MarkDown5       CPI  Unemployment  MDAverage     MDSum     MDMin  \
# 0       -0.395181  1.018774      0.078201  -0.271794 -1.358972 -0.427943
# 1       -0.395181  1.018774      0.078201  -0.271794 -1.358972 -0.427943
# 2       -0.395181  1.018774      0.078201  -0.271794 -1.358972 -0.427943
# 3       -0.395181  1.018774      0.078201  -0.271794 -1.358972 -0.427943
# 4       -0.395181  1.018774      0.078201  -0.271794 -1.358972 -0.427943
# ...           ...       ...           ...        ...       ...       ...
# 412717  -0.191187  0.539003      0.379281  -0.081405 -0.407027 -0.223697
# 412718  -0.191187  0.539003      0.379281  -0.081405 -0.407027 -0.223697
# 412719  -0.191187  0.539003      0.379281  -0.081405 -0.407027 -0.223697
# 412720  -0.191187  0.539003      0.379281  -0.081405 -0.407027 -0.223697
# 412721  -0.191187  0.539003      0.379281  -0.081405 -0.407027 -0.223697
#
#            MDMax
# 0      -0.084662
# 1      -0.084662
# 2      -0.084662
# 3      -0.084662
# 4      -0.084662
# ...          ...
# 412717  0.236078
# 412718  0.236078
# 412719  0.236078
# 412720  0.236078
# 412721  0.236078
#
# [412722 rows x 13 columns]

# %%
SelectK_x_train, SelectK_x_test, SelectK_y_train, SelectK_y_test = train_test_split(df_final_features_SelectK, final_labels, test_size=0.2, random_state=42)
print(SelectK_x_train.shape)
print(SelectK_x_test.shape)
print(SelectK_y_train.shape)
print(SelectK_y_test.shape)
# Out:
# (330177, 13)
# (82545, 13)
# (330177,)
# (82545,)

# %%
SelectK_x_train.to_csv('Processed Dataset/SelectKBest Feature Selection/x_train.csv',index=False)
SelectK_x_test.to_csv('Processed Dataset/SelectKBest Feature Selection/x_test.csv',index=False)
SelectK_y_train.to_csv('Processed Dataset/SelectKBest Feature Selection/y_train.csv',index=False)
SelectK_y_test.to_csv('Processed Dataset/SelectKBest Feature Selection/y_test.csv',index=False)
